# %%
import numpy as np
import matplotlib.pyplot as plt
import pyhepmc as hp
from particle import Particle

# %%
with hp.open("../electron_proton.hepmc") as f:
    event = f.read()

event
# Out:
# <GenEvent momentum_unit=1, length_unit=0, event_number=0, particles=76, vertices=46, run_info=GenRunInfo(tools=[], weight_names=['Weight'], attributes={})>

# %%
particleEnergies = {}

numFinalStateParticles = 0

with hp.open("../electron_proton.hepmc") as f:
    for event in f:
        print(f"Event number: {event.event_number}")
        print(f"Number of particles: {len(event.particles)}")
        for particle in event.particles:
            # Add particle name and energy to particleEnergies if it's a final state particle
            if particle.status == 1:
                numFinalStateParticles += 1
                name = Particle.from_pdgid(particle.pid).name
                energy = particle.momentum.e
                if name not in particleEnergies:
                    particleEnergies[name] = []
                particleEnergies[name].append(energy)

print(f"Total number of final state particles: {numFinalStateParticles}")
# Out:
# Event number: 0
# Number of particles: 76
# Total number of final state particles: 25

# %%
particleEnergies
# Out:
# {'p': [2.8271392540373848, 150.33207696104927],
#  'n~': [3.7770206920963134],
#  'pi-': [9.951736382450962, 15.351043199794589, 0.527520888772843],
#  'pi+': [7.259393291560857, 0.9900588976158359, 2.489130138175154],
#  'gamma': [0.0009188473145738044,
#   0.021534683848275744,
#   0.8615176677152163,
#   0.5991328519444237,
#   30.039219078522915,
#   38.94379629260666,
#   1.6672252483214678,
#   0.05866374653799501,
#   0.10296641465104402],
#  'e-': [16.957939741608115, 1.3281375767950065],
#  'K-': [3.21562135683333, 1.1734453001767613],
#  'K+': [2.552925031175004, 1.7817962568312926],
#  'nu(e)~': [0.19655354265215286]}
